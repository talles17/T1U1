# %%
#1
import pandas as pd

arquivo = 'imd_notas.xlsx'
excel = pd.ExcelFile(arquivo)
dados = excel.parse(0)

a = ['a_ID', 'disciplina_ID', 'status.disciplina']
alunos_id = dados['a_ID']
disciplina = dados['disciplina_ID']

##print (dados[a])
qtd_alunos = [0,0,0,0,0,0]
qtd_alunos = [0,0,0,0,0,0]

for index, row in dados.iterrows() :
  print (row['a_ID'], row['disciplina_ID'], row['status.disciplina'])
    ##if row['a_ID'] == 0:
       ## print (row['disciplina_ID'], row['status.disciplina'])
# Out:
# 0 0 Reprovado
# 0 0 Aprovado
# 1 0 Reprovado
# 2 0 Aprovado
# 3 0 Reprovado
# 3 0 Aprovado
# 4 0 Reprovado
# 4 0 Reprovado
# 5 0 Aprovado
# 6 0 Reprovado
# 6 0 Reprovado
# 6 0 Aprovado
# 7 0 Aprovado
# 8 0 Reprovado
# 8 0 Aprovado
# 9 0 Reprovado
# 9 0 Reprovado
# 9 0 Reprovado
# 10 0 Aprovado
# 10 0 Reprovado
# 11 0 Reprovado
# 12 0 Reprovado
# 12 0 Aprovado
# 13 0 Reprovado
# 13 0 Aprovado
# 14 0 Reprovado
# 14 0 Reprovado
# 14 0 Aprovado
# 15 0 Aprovado
# 16 0 Aprovado
# 17 0 Reprovado
# 17 0 Reprovado
# 17 0 Aprovado
# 17 0 Aprovado
# 18 0 Reprovado
# 19 0 Reprovado
# 20 0 Aprovado
# 21 0 Aprovado
# 22 0 Reprovado
# 23 0 Aprovado
# 24 0 Aprovado
# 25 0 Aprovado
# 26 0 Reprovado
# 26 0 Reprovado
# 26 0 Aprovado
# 27 0 Aprovado
# 28 0 Reprovado
# 29 0 Reprovado
# 29 0 Reprovado
# 30 0 Aprovado
# 31 0 Aprovado
# 32 0 Reprovado
# 33 0 Aprovado
# 34 0 Reprovado
# 34 0 Aprovado
# 35 0 Reprovado
# 35 0 Aprovado
# 36 0 Reprovado
# 37 0 Reprovado
# 37 0 Reprovado
# 37 0 Reprovado
# ...

# %%
#2
##freq_counts = dados['CEP'].value_counts()

disciplinas = [0,1,2,3,4,5,6]
cep_disciplina0 = dict()
cep_disciplina1 = dict()
cep_disciplina2 = dict()
cep_disciplina3 = dict()
cep_disciplina4 = dict()
cep_disciplina5 = dict()
cep_disciplina6 = dict()
for index, row in dados.iterrows() :
    if (row['CEP'] not in cep.keys() and row['status.disciplina'] == 'Aprovado'):
        print (row['CEP'])
        cep_disciplina0[row['CEP']] = 0
        cep_disciplina1[row['CEP']] = 0
        cep_disciplina2[row['CEP']] = 0
        cep_disciplina3[row['CEP']] = 0
        cep_disciplina4[row['CEP']] = 0
        cep_disciplina5[row['CEP']] = 0
        cep_disciplina6[row['CEP']] = 0

for index, row in dados.iterrows() :
    if (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 0):
        cep_disciplina0[row['CEP']] += 1
    elif (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 1):
        cep_disciplina1[row['CEP']] += 1
    elif (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 2):
        cep_disciplina2[row['CEP']] += 1
    elif (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 3):
        cep_disciplina3[row['CEP']] += 1
    elif (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 4):
        cep_disciplina4[row['CEP']] += 1
    elif (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 5):
        cep_disciplina5[row['CEP']] += 1
    elif (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 6):
        cep_disciplina6[row['CEP']] += 1
        

##print(cep_disciplina0)

# %matplotlib inline 
##cep.hist(bins = 20  , range=(0,10))
##cep.plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-184df4025fe2> in <module>()
#      23 for index, row in dados.iterrows() :
#      24     if (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 0):
# ---> 25         cep_disciplina0[row['CEP']] += 1
#      26     elif (row['CEP'] in cep.keys() and row['status.disciplina'] == 'Aprovado' and row['disciplina_ID'] == 1):
#      27         cep_disciplina1[row['CEP']] += 1
#
# KeyError: 59015430

# %%
#3
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
num_cols = dados['ano_disciplina','disciplina_ID']
ax.boxplot(dados[num_cols].values)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/talles/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: ('ano_disciplina', 'disciplina_ID')
#
# During handling of the above exception, another exception occurred:
#
# ...
